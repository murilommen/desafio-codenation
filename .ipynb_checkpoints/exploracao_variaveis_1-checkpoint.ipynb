# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv')

# %%
x_raw = df[['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC']]
y_raw = df['NU_NOTA_MT']

# %%
df = pd.concat([x_raw,y_raw], join='outer', axis=1).dropna(axis=0)
df = df[(df != 0).all(1)]

# %%
X = df[['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',]]
Y = df['NU_NOTA_MT']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2,random_state=None)

# %%
from sklearn.linear_model import LinearRegression

# %%
modelo = LinearRegression()
modelo.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print('R²: {}'.format(modelo.score(X_train,Y_train).round(3)))
# Out:
# R²: 0.396

# %%
y_previsto = modelo.predict(X_test)
y_previsto
# Out:
# array([510.78814349, 429.0030668 , 590.28164614, ..., 568.15159367,
#        373.73247712, 456.88675734])

# %%
print(np.std((y_previsto - Y_test)**2))

from sklearn import metrics
print('R²: %s' % metrics.r2_score(Y_test, y_previsto).round(3))
# Out:
# 8277.572994760467
# R²: 0.427

# %%
sns.pairplot(x_vars=['NU_NOTA_LC','NU_NOTA_CN','NU_NOTA_CH'], y_vars='NU_NOTA_MT', data=df, 
                 kind='reg', height=5)

# %% [markdown]
# Pode-se ver uma correlação das variáveis com o que se deseja, mas talvez não seja uma relação linear

# %%
import statsmodels.api as sm 

X_train_const = sm.add_constant(X_train)
modelo_stats = sm.OLS(Y_train, X_train, hasconst=True).fit()
# Out:
# /home/murilomen/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
print(modelo_stats.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             NU_NOTA_MT   R-squared:                       0.396
# Model:                            OLS   Adj. R-squared:                  0.396
# Method:                 Least Squares   F-statistic:                     2642.
# Date:                Fri, 17 May 2019   Prob (F-statistic):               0.00
# Time:                        14:53:56   Log-Likelihood:                -46413.
# No. Observations:                8067   AIC:                         9.283e+04
# Df Residuals:                    8064   BIC:                         9.285e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# NU_NOTA_CN     0.5543      0.015     36.756      0.000       0.525       0.584
# NU_NOTA_CH     0.2521      0.017     14.667      0.000       0.218       0.286
# NU_NOTA_LC     0.1664      0.017      9.879      0.000       0.133       0.199
# ==============================================================================
# Omnibus:                      173.369   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              184.304
# Skew:                           0.363   Prob(JB):                     9.52e-41
# Kurtosis:                       3.144   Cond. No.                         23.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Transformação logarítmica

# %% [markdown]
# Tentativa de ajustar a curva tirando o logarítmo de cada variável

# %%
df['log_NU_NOTA_CN'] = np.log(df['NU_NOTA_CN']+1.0)
df['log_NU_NOTA_CH'] = np.log(df['NU_NOTA_CH']+1.0)
df['log_NU_NOTA_LC'] = np.log(df['NU_NOTA_LC']+1.0)
df['log_NU_NOTA_MT'] = np.log(df['NU_NOTA_MT']+1.0)
df['log_NU_NOTA_REDACAO'] = np.log(df['NU_NOTA_REDACAO']+1.0)


x_raw = df[['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_REDACAO',
            'log_NU_NOTA_CN', 'log_NU_NOTA_CH', 'log_NU_NOTA_LC', 'log_NU_NOTA_REDACAO']]
y_raw = df[['NU_NOTA_MT','log_NU_NOTA_MT']]

# %%
df = pd.concat([x_raw,y_raw], join='outer', axis=1).dropna(axis=0)
df = df[(df != 0).all(1)]

# %% [markdown]
# Primeiro tirando o logarítmo das variáveis X

# %%
X = df[['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC','NU_NOTA_REDACAO']]
Y = df['log_NU_NOTA_MT']

# %%
Y.head(), X.head()
# Out:
# (0    5.992464
#  1    6.132964
#  5    5.901266
#  6    6.273254
#  7    6.341593
#  Name: log_NU_NOTA_MT, dtype: float64,
#     NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_REDACAO
#  0       436.3       495.4       581.2            520.0
#  1       474.5       544.1       599.0            580.0
#  5       439.7       583.2       410.9            620.0
#  6       420.1       604.2       484.5            560.0
#  7       619.6       625.8       611.2            620.0)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2,random_state=None)

# %%
Y_train.head(), X_train.head()
# Out:
# (9020     6.129486
#  4795     6.374343
#  11232    5.954801
#  1948     6.294897
#  9738     6.273820
#  Name: log_NU_NOTA_MT, dtype: float64,
#         NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_REDACAO
#  9020        529.9       587.9       585.7            560.0
#  4795        513.0       600.1       583.4            580.0
#  11232       409.1       489.2       491.3            480.0
#  1948        412.4       476.4       492.3            420.0
#  9738        464.4       540.0       518.2            580.0)

# %%
modelo.fit(X_train,Y_train)
print('R²: {}'.format(modelo.score(X_train,Y_train).round(3)))
# Out:
# R²: 0.375

# %%
y_previsto = modelo.predict(X_test)

print(np.std((np.exp(y_previsto) - np.exp(Y_test))**2))

from sklearn import metrics
print('R²: %s' % metrics.r2_score(Y_test, y_previsto).round(3))
# Out:
# 7987.0000225498425
# R²: 0.397

# %%
modelo_stats.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             NU_NOTA_MT   R-squared:                       0.396
# Model:                            OLS   Adj. R-squared:                  0.396
# Method:                 Least Squares   F-statistic:                     2642.
# Date:                Fri, 17 May 2019   Prob (F-statistic):               0.00
# Time:                        23:56:16   Log-Likelihood:                -46413.
# No. Observations:                8067   AIC:                         9.283e+04
# Df Residuals:                    8064   BIC:                         9.285e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# NU_NOTA_CN     0.5543      0.015     36.756      0.000       0.525       0.584
# NU_NOTA_CH     0.2521      0.017     14.667      0.000       0.218       0.286
# NU_NOTA_LC     0.1664      0.017      9.879      0.000       0.133       0.199
# ==============================================================================
# Omnibus:                      173.369   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              184.304
# Skew:                           0.363   Prob(JB):                     9.52e-41
# Kurtosis:                       3.144   Cond. No.                         23.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Simplesmente transformar os dados para logarítmo não resolveu o problema

# %%
sns.pairplot(x_vars=['NU_NOTA_LC','NU_NOTA_CN','NU_NOTA_CH', 'log_NU_NOTA_REDACAO'], y_vars='NU_NOTA_MT', data=df, 
                 kind='reg', height=5)

# %%
sns.pairplot(x_vars=['log_NU_NOTA_LC','log_NU_NOTA_CN','log_NU_NOTA_CH'], y_vars='log_NU_NOTA_MT', data=df, 
                 kind='reg', height=5)

# %%
sns.pairplot(x_vars=['log_NU_NOTA_LC','log_NU_NOTA_CN','log_NU_NOTA_CH'], y_vars='NU_NOTA_MT', data=df, 
                 kind='reg', height=5)

# %% [markdown]
# # Testando com função polinomial

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 10)

# %%
X_poly = poly_reg.fit_transform(X_train)

# %%
modelo = LinearRegression()
modelo.fit(X_poly, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
X_poly2 = poly_reg.fit_transform(X_test)

# %%
y_previsto2 = modelo.predict(X_poly2)

# %%
from sklearn.metrics import r2_score
print('R²: {}'.format(r2_score(Y_test,y_previsto2).round(3)))
# Out:
# R²: -0.238

# %%
import pandas as pd
df = pd.read_csv('train.csv')

# %%
x1 = df[['NU_IDADE','TP_COR_RACA','CO_UF_RESIDENCIA']]
y1 = df['NU_NOTA_MT']

# %%
sns.pairplot(x_vars=['TP_COR_RACA','CO_UF_RESIDENCIA'], y_vars='NU_NOTA_MT', data=df, 
                 kind='reg', height=5)

# %%
sns.pairplot(x_vars=['NU_NOTA_REDACAO'], y_vars='NU_NOTA_MT', data=df, 
                 kind='reg', height=5)

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(x='TP_COR_RACA', y='NU_NOTA_MT', data=df, fliersize=8, notch=True)

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(x='CO_UF_RESIDENCIA', y='NU_NOTA_MT', data=df, fliersize=8, notch=True)

# %%
sns.distplot(df['NU_NOTA_LC'].dropna())

# %%
sns.distplot(df['NU_NOTA_REDACAO'].dropna())

# %%
sns.distplot(df['NU_NOTA_CH'].dropna())

# %%
sns.distplot(df['NU_NOTA_CN'].dropna())

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(x='TP_SEXO', y='NU_NOTA_MT', data=df, fliersize=8, notch=True)

# %%
sns.pairplot(x_vars='NU_IDADE', y_vars='NU_NOTA_MT', data=df, height=5)

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(x='TP_ESTADO_CIVIL', y='NU_NOTA_MT', data=df, fliersize=8, notch=True)

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(x='TP_ANO_CONCLUIU', y='NU_NOTA_MT', data=df, fliersize=8, notch=True)

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(x='TP_ESCOLA', y='NU_NOTA_MT', data=df, fliersize=8, notch=True)

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(x='TP_ENSINO', y='NU_NOTA_MT', data=df, fliersize=8, notch=True)

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(x='IN_TREINEIRO', y='NU_NOTA_MT', data=df, fliersize=8, notch=True)

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(x='IN_DEFICIENCIA_AUDITIVA', y='NU_NOTA_MT', data=df, fliersize=8, notch=True)

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(x='IN_DEFICIENCIA_FISICA', y='NU_NOTA_MT', data=df, fliersize=8, notch=True)

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(x='IN_DEFICIENCIA_MENTAL', y='NU_NOTA_MT', data=df, fliersize=8, notch=True)

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(x='IN_DEFICIT_ATENCAO', y='NU_NOTA_MT', data=df, fliersize=8, notch=False)

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(x='IN_SABATISTA', y='NU_NOTA_MT', data=df, fliersize=8, notch=False)

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(x='IN_CERTIFICADO', y='NU_NOTA_MT', data=df, fliersize=8, notch=False)

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(x='CO_UF_PROVA', y='NU_NOTA_MT', data=df, fliersize=8, notch=False)
